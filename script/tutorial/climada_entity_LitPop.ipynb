# %% [markdown]
# # LitPop class
#
# This class is a data model of economic exposure. It models countries' gridded exposure by interpolating an macroeconomic indicator through the product of night light intensities and gridded population count for a specific year. Asset value is distributed to the grid proportzional to LitPop. LitPop at each pixel is calculated in the script as:
#
# $Lit^mPop^n = Lit^m * Pop^n$, with $exponents = [m, n] \in \N^+$ (Default values are $m=n=1$).
#
# The night light images used are the following:
# - year 2012 and 2016: https://earthobservatory.nasa.gov/Features/NightLights (15 arcsec resolution (~500m))
#
# The gridded population count data used are the following:
# - Gridded Population of the World (GPW), v4: Population Count, v4.10 (2000, 2005, 2010, 2015, 2020)
# http://sedac.ciesin.org/data/set/gpw-v4-population-count-rev10
# The population data from GWP needs to be downloaded manually as TIFF from this site and placed in the system data folder of climada, i.e.: climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
# Always the GPW file of the year closest to the target year is required.
# All other required data is acquired automatically.
#
# Available macroeconomic indicators can be selected via the variable fin_mode:
# - 'pc': produced capital (Source: World Bank DataBank), incl. manufactured or built assets such as machinery, equipment, and physical structures (pc is in constant 2014 USD, data is available for the years 1995, 2000, 2005, 2010, 2014)
# - 'gdp': gross-domestic product (Source: World Bank)
# - 'income_group': gdp multiplied by country's income group+1
# - 'nfw': households' non-financial wealth (Source: Credit Suisse, of households only)
# - 'tw': households' total wealth (Source: Credit Suisse, of households only)
#
# Regarding the GDP (nominal GDP at current USD) and income group values, they are obtained from the [World Bank](https://data.worldbank.org) using the [pandas-datareader](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) API. If a value is missing, the value of the closest year is considered. When no values are provided from the World Bank, we use the [Natural Earth](https://www.naturalearthdata.com) repository values.
#
# The `LitPop` class inherits from the [`Exposures`](climada_entity_Exposures.ipynb#Exposures-class) class. It provides a `set_country()` method which enables to model a country using different settings. The first time a night light image is used, it is downloaded and stored locally. This might take some time.

# %%
# Import required packages:
import numpy as np
import pandas as pd
from matplotlib import colors
from cartopy.io import shapereader
from iso3166 import countries as iso_cntry

from climada.entity.exposures.litpop import LitPop

# %% [markdown]
# ## Country Exposure
# In the following, we will create exposure data sets and plots for a variety of countries, comparing different settings.
# ### Default Settings

# %%
# Initiate a default LitPop exposure entity for Switzerland (ISO3-Code 'CHE'):
ent = LitPop()
ent.set_country('CHE')

""" In case you encounter an error here, because the GPW data is missing: The gridded population count data used are the following:
- Gridded Population of the World (GPW), v4: Population Count, v4.10 (2000, 2005, 2010, 2015, 2020).
http://sedac.ciesin.org/data/set/gpw-v4-population-count-rev10
The population data from GWP needs to be downloaded manually as TIFF
from this site and placed in the system data folder of climada,
i.e.: climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
"""
# Out:
# 2019-02-14 13:58:31,147 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30.0 arcsec.
# 2019-02-14 13:58:31,148 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/eberenzs/Documents/Projects/climada_python/data/system
# 2019-02-14 13:58:31,149 - climada.entity.exposures.litpop - DEBUG - Reading and cropping neccessary BM files.
# 2019-02-14 13:58:31,150 - climada.entity.exposures.litpop - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-02-14 13:58:33,663 - climada.entity.exposures.litpop - DEBUG - Reading file completed: /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-02-14 13:58:33,664 - climada.entity.exposures.litpop - DEBUG - Resizing image according to chosen resolution
# 2019-02-14 13:58:43,807 - climada.entity.exposures.litpop - DEBUG - Cutting the bounding box took 4 s.
# 2019-02-14 13:58:43,974 - climada.entity.exposures.litpop - DEBUG - Reducing to one dimension...
# 2019-02-14 13:58:44,046 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-02-14 13:58:44,047 - climada.entity.exposures.gpw_import - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
# 2019-02-14 13:58:54,676 - climada.util.finance - INFO - GDP CHE 2014: 7.092e+11.
# 2019-02-14 13:58:55,145 - climada.util.finance - INFO - GDP CHE 2016: 6.687e+11.
# 2019-02-14 13:58:55,254 - climada.entity.exposures.litpop - DEBUG - Extracting subshapes and detecting enclaves...
# 2019-02-14 13:58:55,611 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-02-14 13:58:56,087 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 26.36s
# 2019-02-14 13:58:56,088 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-02-14 13:58:56,088 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-02-14 13:58:56,089 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-02-14 13:58:56,089 - climada.entity.exposures.base - INFO - cover not set.
# 2019-02-14 13:58:56,089 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-02-14 13:58:56,090 - climada.entity.exposures.base - INFO - Setting geometry attribute.
# '\nIn case you encounter an error here, because the GPW data is missing:\nThe gridded population count data used are the following:\n- Gridded Population of the World (GPW), v4: Population Count, v4.10 (2000, 2005, 2010, 2015, 2020)\nhttp://sedac.ciesin.org/data/set/gpw-v4-population-count-rev10\nThe population data from GWP needs to be downloaded manually as TIFF\nfrom this site and placed in the system data folder of climada,\ni.e.: climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif\n'

# %% [markdown]
# ### Plotting
# The exposure entity was initiated using the default setting, i.e. a resolution of 30 arcsec and produced capital 'pc' as total asset value, using the exponents $[1, 1]$.
#
# If the init worked, we can now plot a map of Switzerland's exposure:

# %%
# plot exposure with major towns (pop_name=True):
ent.plot_hexbin(pop_name=True)
# plot exposure with log-normal colormap:
norm=colors.LogNorm(vmin=10.0e2, vmax=3.0e9)
ent.plot_hexbin(norm=norm)
# Out:
# (<Figure size 648x936 with 2 Axes>,
#  array([[<cartopy.mpl.geoaxes.GeoAxesSubplot object at 0x1a340f91d0>]],
#        dtype=object))

# %% [markdown]
# ### Settings: fin_mode
# Instead on produced capital, we can also downscale other available macroeconomic indicators as estimates of asset value.
# The indicator can be set via the variable fin_mode:
#
#     'pc': produced capital (Source: World Bank DataBank), incl. manufactured or built assets such as machinery, equipment, and physical structures (pc is in constant 2014-USD, data available for the years 1995, 2000, 2005, 2010, 2014)
#     'gdp': gross-domestic product (Source: World Bank)
#     'income_group': gdp multiplied by country's income group+1
#     'nfw': households' non-financial wealth (Source: Credit Suisse, of households only)
#     'tw': households' total wealth (Source: Credit Suisse, of households only)
#
# Let's initiate the entity for Switzerland with the financial mode "income_group":

# %%
# Initiate a default LitPop exposure entity for Switzerland (ISO3-Code 'CHE'):

ent = LitPop()
ent.set_country('CHE', fin_mode='income_group') # try other fin_modes: 'gdp', 'nfw', 'pc'
# plot exposure:
ent.plot_hexbin(pop_name=True)
# Out:
# 2019-02-14 11:14:03,597 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30.0 arcsec.
# 2019-02-14 11:14:03,598 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/eberenzs/Documents/Projects/climada_python/data/system
# 2019-02-14 11:14:03,598 - climada.entity.exposures.litpop - DEBUG - Reading and cropping neccessary BM files.
# 2019-02-14 11:14:03,599 - climada.entity.exposures.litpop - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-02-14 11:14:06,130 - climada.entity.exposures.litpop - DEBUG - Reading file completed: /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-02-14 11:14:06,130 - climada.entity.exposures.litpop - DEBUG - Resizing image according to chosen resolution
# 2019-02-14 11:14:15,740 - climada.entity.exposures.litpop - DEBUG - Cutting the bounding box took 3 s.
# 2019-02-14 11:14:15,901 - climada.entity.exposures.litpop - DEBUG - Reducing to one dimension...
# 2019-02-14 11:14:15,969 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-02-14 11:14:15,969 - climada.entity.exposures.gpw_import - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
# 2019-02-14 11:14:26,350 - climada.util.finance - INFO - GDP CHE 2016: 6.687e+11.
# 2019-02-14 11:14:26,414 - climada.util.finance - INFO - Income group CHE 2016: 4.
# 2019-02-14 11:14:26,517 - climada.entity.exposures.litpop - DEBUG - Extracting subshapes and detecting enclaves...
# 2019-02-14 11:14:26,826 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-02-14 11:14:27,261 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 25.12s
# 2019-02-14 11:14:27,262 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-02-14 11:14:27,262 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-02-14 11:14:27,263 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-02-14 11:14:27,264 - climada.entity.exposures.base - INFO - cover not set.
# 2019-02-14 11:14:27,266 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-02-14 11:14:27,266 - climada.entity.exposures.base - INFO - Setting geometry attribute.
# (<Figure size 648x936 with 2 Axes>,
#  array([[<cartopy.mpl.geoaxes.GeoAxesSubplot object at 0x1a2b943080>]],
#        dtype=object))

# %% [markdown]
# This map shows like the default one above, the only difference is the absolute value per pixel: Note that the range of the color scale has changed because the total asset value estimated with the income_group mode is larger than produced capital stock.
#
# ### Settings: resolution (res_arcsec) and reference_year
#
# We can also change the resolution in arc seconds to one of these values: 30, 60, 120, 300, 600, 3600.
#
# $30 arcsec \approx 1 km$.
#
# $3600 arcsec = 1\degree \approx 110 km$.
#
# Additionally, we can change the year our exposure is supposed to represent. For this, nightlight and population data  are used that are closest to the requested years. Macroeconomic indicators like produced capital are interpolated from available data or scaled proportional to GDP.
#
# Let's estimate a produced capital exposure map for Switzerland in 2017 with a resolution of 300 arcsec:

# %%
ent.set_country('CHE', fin_mode='pc', res_arcsec=300, reference_year=2017)
# plot exposure with larger line width for better visibility:
ent.plot_hexbin(linewidth=7)
# Instead of linewight, the gridsize can be adjusted for better visibility (low values --> big markers).
# Warning: If gridsize is changed, the plot doesn't reflect the actual data's grid anymore:
ent.plot_hexbin(gridsize=20)
# Out:
# (<Figure size 648x936 with 2 Axes>,
#  array([[<cartopy.mpl.geoaxes.GeoAxesSubplot object at 0x1a29589470>]],
#        dtype=object))

# %% [markdown]
# As can you can read from the logger output above the plot, the following data time steps were used to estimate 2017's exposure:
# - GPW Population of 2015 (closest year)
# - BlackMarble Nightlights of 2016 (closest year)
# - Produced capital of 2014 (closest year), inflated proportional to the GDP increase from 2014 to 2017. This is an inflation of roughly 4.5% in this case.
#
#
# ### Settings: exponents of $Lit^mPop^n$
#
# LitPop per pixel is the product of the exponents of nightlights+1 (Lit) and Population count (Pop).
#
# $Lit^mPop^n = Lit^m * Pop^n$, with $exponents = [m, n] \in \N_0$ (Default values are $m=n=1$).
#
# We can also change m and n.
#
# **For countries with badly resolved population data (i.e. Jamaica or Uzbekistan), it can make sense to use nightlights only, i.e. an high exponent of Lit instead of LitPop.**
# Note that if Pop is not used, $Lit = nightlights$ instead of $nightlights+1$.
#
# Let's compare exposure maps for $LitPop=Lit^1Pop^1$ (default); $Lit^3$; and $Pop^1$ Jamaica at a resolution of 60 arcsec.
#
# Please execute one cell after the other:

# %%
ent = LitPop()
res = 60
country = 'JAM' # Try different countries, i.e. 'JAM', 'CHE', 'RWA', 'MEX'
markersize = 3
gridsize = 70
buffer_deg=.02
# The arguments 'exponent' is used to set the power with which Lit and Pop go into LitPop:
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[0, 1])  # Population only

ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer_deg=buffer_deg)
# buffer_deg adds a buffer around the plotted data to show the whole country
"""Lit^0 * Pop^1"""
# Out:
# 'Lit^0 * Pop^1'

# %%
# JAMAICA:
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[3, 0]) # Nightlights^3 only
ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer_deg=buffer_deg)
"""Lit^3"""
# Out:
# 2019-02-14 14:40:47,263 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 60 arcsec.
# 2019-02-14 14:40:47,264 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/eberenzs/Documents/Projects/climada_python/data/system
# 2019-02-14 14:40:47,265 - climada.entity.exposures.litpop - DEBUG - Reading and cropping neccessary BM files.
# 2019-02-14 14:40:47,266 - climada.entity.exposures.litpop - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-02-14 14:40:49,573 - climada.entity.exposures.litpop - DEBUG - Reading file completed: /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-02-14 14:40:49,574 - climada.entity.exposures.litpop - DEBUG - Resizing image according to chosen resolution
# 2019-02-14 14:40:53,307 - climada.entity.exposures.litpop - DEBUG - Cutting the bounding box took 2 s.
# 2019-02-14 14:40:53,394 - climada.entity.exposures.litpop - DEBUG - Reducing to one dimension...
# 2019-02-14 14:40:53,402 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-02-14 14:40:53,403 - climada.entity.exposures.gpw_import - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
# 2019-02-14 14:41:12,710 - climada.entity.exposures.litpop - DEBUG - Extracting subshapes and detecting enclaves...
# 2019-02-14 14:41:12,720 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-02-14 14:41:12,755 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 27.0s
# 2019-02-14 14:41:12,756 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-02-14 14:41:12,756 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-02-14 14:41:12,757 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-02-14 14:41:12,758 - climada.entity.exposures.base - INFO - cover not set.
# 2019-02-14 14:41:12,758 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-02-14 14:41:12,759 - climada.entity.exposures.base - INFO - Setting geometry attribute.
# 'Lit^3'

# %%
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[1, 1]) # Default LitPop [1, 1]
ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer_deg=buffer_deg)
"""Lit^1 * Pop^1"""
# Out:
# 2019-02-14 14:41:25,060 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 60 arcsec.
# 2019-02-14 14:41:25,060 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/eberenzs/Documents/Projects/climada_python/data/system
# 2019-02-14 14:41:25,061 - climada.entity.exposures.litpop - DEBUG - Reading and cropping neccessary BM files.
# 2019-02-14 14:41:25,061 - climada.entity.exposures.litpop - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-02-14 14:41:27,322 - climada.entity.exposures.litpop - DEBUG - Reading file completed: /Users/eberenzs/Documents/Projects/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-02-14 14:41:27,323 - climada.entity.exposures.litpop - DEBUG - Resizing image according to chosen resolution
# 2019-02-14 14:41:31,109 - climada.entity.exposures.litpop - DEBUG - Cutting the bounding box took 2 s.
# 2019-02-14 14:41:31,192 - climada.entity.exposures.litpop - DEBUG - Reducing to one dimension...
# 2019-02-14 14:41:31,200 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-02-14 14:41:31,200 - climada.entity.exposures.gpw_import - DEBUG - Trying to import the file /Users/eberenzs/Documents/Projects/climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
# 2019-02-14 14:41:46,795 - climada.entity.exposures.litpop - DEBUG - Extracting subshapes and detecting enclaves...
# 2019-02-14 14:41:46,806 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-02-14 14:41:46,841 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 23.22s
# 2019-02-14 14:41:46,842 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-02-14 14:41:46,842 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-02-14 14:41:46,843 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-02-14 14:41:46,845 - climada.entity.exposures.base - INFO - cover not set.
# 2019-02-14 14:41:46,845 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-02-14 14:41:46,846 - climada.entity.exposures.base - INFO - Setting geometry attribute.
# 'Lit^1 * Pop^1'

# %% [markdown]
# For **Switzerland**, population is resolved on the 3rd administrative level, with 2538 distinct geographical units. Therefore, the purely population-based map is highly resolved.
#
# For **Jamaica**, population is only resolved on the 1st administrative level, with only 14 distinct geographical units. Therefore, the purely population-based map shows large monotonous patches. Still, the combination of Lit and Pop results in a concentration of asset value estimates around the capital city Kingston.

# %% [markdown]
# ### Multiple countries
# Computing LitPop-entities for a list of countries and plot a log-normal exposure map:

# %%
# GDP-Entity for Tanzania, Rwanda, and Burundi:
ent = LitPop()
countries_list = ['BDI', 'RWA', 'TZA']
ent.set_country(countries_list, res_arcsec=120, reference_year=2014, fin_mode='gdp')

# %%
# Plotting:
ent.plot_hexbin(linewidth=2, buffer_deg=.3) # linear colormap
ent.plot_hexbin(linewidth=2, buffer_deg=.3, bins='log') # logarithmic colormap
norm=colors.LogNorm(vmin=1.5e2, vmax=1.5e9) # setting range for the log-normal scale
ent.plot_hexbin(linewidth=2, buffer_deg=.3, norm=norm) # log-normal colormap from USD 150 to USD 1'500'000'000.
"""GDP downscaling with LitPop for Tanzania, Rwanda, and Burundi (2014). Linear, logarithmic, and log-normal colorbars"""
# Out:
# 'GDP downscaling with LitPop for Tanzania, Rwanda, and Burundi (2014). Linear, logarithmic, and log-normal colorbars'

# %% [markdown]
# # LitPop class
#
# This class is a data model of economic exposure. It models countries' gridded exposure by interpolating an macroeconomic indicator through the product of night light intensities and gridded population count for a specific year. Asset value is distributed to the grid proportzional to LitPop. LitPop at each pixel is calculated in the script as:
#
# $Lit^mPop^n = Lit^m * Pop^n$, with $exponents = [m, n] \in \N_0$ (Default values are $m=n=1$).
#
# The night light images used are the following:
# - year 2012 and 2016: https://earthobservatory.nasa.gov/Features/NightLights (15 arcsec resolution (~500m))
#
# The gridded population count data used are the following:
# - Gridded Population of the World (GPW), v4: Population Count, v4.10, v4.11 or later versions (2000, 2005, 2010, 2015, 2020)
# http://sedac.ciesin.columbia.edu/data/collection/gpw-v4/sets/browse
# (i.e. http://sedac.ciesin.org/data/set/gpw-v4-population-count-rev10 or
# http://sedac.ciesin.org/data/set/gpw-v4-population-count-rev11 etc.)
#
# Always the GPW file of the year closest to the target year is required.
# To download GPW data you need to register on the SEDAC website (for free).
# Then you can access the download site, i.e.: http://sedac.ciesin.columbia.edu/data/set/gpw-v4-population-count-rev11/data-download.
# There, choose the settings as shown, ticking the box of the years you need:
# ![Screenshot%202019-04-18%20at%2010.52.04.png](attachment:Screenshot%202019-04-18%20at%2010.52.04.png)
# The population data from GWP needs to be downloaded manually as TIFF from this site and placed in the system data folder of climada, i.e.: climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif.
#
# Direct download links are avilable, also for older versions, i.e.:
# http://sedac.ciesin.columbia.edu/downloads/data/gpw-v4/gpw-v4-population-count-rev10/gpw-v4-population-count-rev10_2015_30_sec_tif.zip,
# or:
# http://sedac.ciesin.columbia.edu/downloads/data/gpw-v4/gpw-v4-population-count-rev11/gpw-v4-population-count-rev11_2015_30_sec_tif.zip
#
# All other required data is acquired automatically.
#
# Available macroeconomic indicators can be selected via the variable fin_mode:
# - 'pc': produced capital (Source: World Bank DataBank), incl. manufactured or built assets such as machinery, equipment, and physical structures (pc is in constant 2014 USD, data is available for the years 1995, 2000, 2005, 2010, 2014). The pc-data is stored in the subfolder *data/system/Wealth-Accounts_CSV/*. Source: https://datacatalog.worldbank.org/dataset/wealth-accounting
# - 'gdp': gross-domestic product (Source: World Bank)
# - 'income_group': gdp multiplied by country's income group+1
# - 'nfw': households' non-financial wealth (Source: Credit Suisse, of households only)
# - 'tw': households' total wealth (Source: Credit Suisse, of households only)
#
# Regarding the GDP (nominal GDP at current USD) and income group values, they are obtained from the [World Bank](https://data.worldbank.org) using the [pandas-datareader](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) API. If a value is missing, the value of the closest year is considered. When no values are provided from the World Bank, we use the [Natural Earth](https://www.naturalearthdata.com) repository values.
#
#
# _Initiating LitPop():_
#
# The `LitPop` class inherits from the [`Exposures`](climada_entity_Exposures.ipynb#Exposures-class) class. It provides a `set_country()` method which enables to compute exposure data for a country using different settings and input data. The first time a nightlight image is used, it is downloaded and stored locally. This might take some time.
#
# *NOTE / Downloading existing LitPop exposure data:*
#
# Readily computed LitPop exposure data, distributing produced capital of 2014 at a resolution of 30 arcsec can be downloaded from the ETH Research Repository: https://doi.org/10.3929/ethz-b-000331316.
# The dataset contains gridded data for more than 200 countries as CSV files. [These can be imported into Python using the Exposures class, i.e. *Exposures(pd.read_csv(file_name))*]

# %%
# Import required packages:
import numpy as np
import pandas as pd
from matplotlib import colors
from iso3166 import countries as iso_cntry

from climada.entity.exposures.litpop import LitPop
# Out:
# 2019-07-30 09:14:17,138 - climada - DEBUG - Loading default config file: /Users/aznarsig/Documents/Python/climada_python/climada/conf/defaults.conf

# %% [markdown]
# ## Country Exposure
# In the following, we will create exposure data sets and plots for a variety of countries, comparing different settings.
# ### Default Settings

# %%
# Initiate a default LitPop exposure entity for Switzerland (ISO3-Code 'CHE'):
ent = LitPop()
ent.set_country('CHE')

""" In case you encounter an error here, because the GPW data is missing: The gridded population count data used are the following:
- Gridded Population of the World (GPW), v4: Population Count, v4.10 or later (2000, 2005, 2010, 2015, 2020).
http://sedac.ciesin.columbia.edu/data/collection/gpw-v4/sets/browse
The population data from GWP needs to be downloaded manually as TIFF
from this site and placed in the system data folder of climada,
i.e.: climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif
"""
# Out:
# 2019-07-30 09:14:20,693 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30.0 arcsec.
# 2019-07-30 09:14:20,694 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:14:20,696 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:14:38,589 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:14:38,590 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:14:38,591 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:14:51,851 - climada.util.finance - INFO - GDP CHE 2014: 7.092e+11.
# 2019-07-30 09:14:52,461 - climada.util.finance - INFO - GDP CHE 2016: 6.702e+11.
# 2019-07-30 09:14:53,067 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:14:53,075 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:14:53,704 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 34 s
# 2019-07-30 09:14:53,704 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:14:53,705 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:14:53,707 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:14:53,708 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:14:53,709 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:14:53,709 - climada.entity.exposures.base - INFO - geometry not set.
# ' In case you encounter an error here, because the GPW data is missing: The gridded population count data used are the following:\n- Gridded Population of the World (GPW), v4: Population Count, v4.10 or later (2000, 2005, 2010, 2015, 2020).\nhttp://sedac.ciesin.columbia.edu/data/collection/gpw-v4/sets/browse\nThe population data from GWP needs to be downloaded manually as TIFF\nfrom this site and placed in the system data folder of climada,\ni.e.: climada_python/data/system/gpw_v4_population_count_rev10_2015_30_sec.tif\n'

# %% [markdown]
# ### Plotting
# The exposure entity was initiated using the default setting, i.e. a resolution of 30 arcsec and produced capital 'pc' as total asset value, using the exponents $[1, 1]$.
#
# If the init worked, we can now plot a map of Switzerland's exposure.
# We can get a good impression of the exposure distribution in Switzerland by comparing plots with linear and log-normal colormaps:
#
# (please refer to the exposure tutorial *climada_entity_Exposures.ipynb* for more info on the visualization of exposure data.)

# %%
ent.set_geometry_points()
# plot exposure with linear colormap and major towns (pop_name=True):
ent.plot_hexbin(pop_name=True)
# plot exposure with log-normal colormap:
norm=colors.LogNorm(vmin=500, vmax=4.0e9)
ent.plot_hexbin(norm=norm)
# Out:
# 2019-07-30 09:14:53,762 - climada.util.coordinates - INFO - Setting geometry points.
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '

# %% [markdown]
# ### Settings: fin_mode
# Instead on produced capital, we can also downscale other available macroeconomic indicators as estimates of asset value.
# The indicator can be set via the variable fin_mode:
#
#     'pc': produced capital (Source: World Bank DataBank), incl. manufactured or built assets such as machinery, equipment, and physical structures (pc is in constant 2014-USD, data available for the years 1995, 2000, 2005, 2010, 2014)
#     'gdp': gross-domestic product (Source: World Bank)
#     'income_group': gdp multiplied by country's income group+1
#     'nfw': households' non-financial wealth (Source: Credit Suisse, of households only)
#     'tw': households' total wealth (Source: Credit Suisse, of households only)
#
# Let's initiate the entity for Switzerland with the financial mode "income_group":

# %%
# Initiate a default LitPop exposure entity for Switzerland (ISO3-Code 'CHE'):

ent = LitPop()
ent.set_country('CHE', fin_mode='income_group') # try other fin_modes: 'gdp', 'nfw', 'pc'
# plot exposure:
ent.plot_hexbin(pop_name=True)
# Out:
# 2019-07-30 09:15:10,802 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30.0 arcsec.
# 2019-07-30 09:15:10,803 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:15:10,804 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:15:25,572 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:15:25,573 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:15:25,574 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:15:37,662 - climada.util.finance - INFO - GDP CHE 2016: 6.702e+11.
# 2019-07-30 09:15:37,732 - climada.util.finance - INFO - Income group CHE 2016: 4.
# 2019-07-30 09:15:38,220 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:15:38,227 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:15:38,740 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 29 s
# 2019-07-30 09:15:38,741 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:15:38,741 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:15:38,742 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:15:38,743 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:15:38,744 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:15:38,746 - climada.entity.exposures.base - INFO - geometry not set.
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '

# %% [markdown]
# This map shows like the default one above, the only difference is the absolute value per pixel: Note that the range of the color scale has changed because the total asset value estimated with the income_group mode is larger than produced capital stock.
#
# ### Settings: resolution (res_arcsec) and reference_year
#
# We can also change the resolution in arc seconds to one of these values: 30, 60, 120, 300, 600, 3600.
#
# $30 arcsec \approx 1 km$.
#
# $3600 arcsec = 1\degree \approx 110 km$.
#
# Additionally, we can change the year our exposure is supposed to represent. For this, nightlight and population data  are used that are closest to the requested years. Macroeconomic indicators like produced capital are interpolated from available data or scaled proportional to GDP.
#
# Let's estimate a produced capital exposure map for Switzerland in 2017 with a resolution of 300 arcsec:

# %%
ent = LitPop()
ent.set_country('CHE', fin_mode='pc', res_arcsec=300, reference_year=2017)
ent.set_geometry_points()
# plot exposure with larger line width for better visibility:
ent.plot_hexbin(linewidth=7)
# Instead of linewight, the gridsize can be adjusted for better visibility (low values --> big markers).
# Warning: If gridsize is changed, the plot doesn't reflect the actual data's grid anymore,
# (please refer to the exposure tutorial *climada_entity_Exposures.ipynb* 
# for more info on the visualization of exposure data.)
ent.plot_hexbin(gridsize=20)
# Out:
# 2019-07-30 09:15:46,466 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 300 arcsec.
# 2019-07-30 09:15:46,467 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:15:46,467 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:15:49,694 - climada.entity.exposures.gpw_import - INFO - Reference year: 2017. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:15:49,694 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:15:49,695 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:16:02,431 - climada.util.finance - INFO - GDP CHE 2014: 7.092e+11.
# 2019-07-30 09:16:03,119 - climada.util.finance - INFO - GDP CHE 2017: 6.790e+11.
# 2019-07-30 09:16:03,280 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:16:03,281 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:16:03,304 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 18 s
# 2019-07-30 09:16:03,305 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:16:03,305 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:16:03,306 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:16:03,306 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:16:03,307 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:16:03,308 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:16:03,319 - climada.util.coordinates - INFO - Setting geometry points.
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '

# %% [markdown]
# As can you can read from the logger output above the plot, the following data time steps were used to estimate 2017's exposure:
# - GPW Population of 2015 (closest year)
# - BlackMarble Nightlights of 2016 (closest year)
# - Produced capital of 2014 (closest year), inflated proportional to the GDP increase from 2014 to 2017. This is an inflation of roughly 4.5% in this case.
#
#
# ### Settings: exponents of $Lit^mPop^n$
#
# LitPop per pixel is the product of the exponents of nightlights+1 (Lit) and Population count (Pop).
#
# $Lit^mPop^n = Lit^m * Pop^n$, with $exponents = [m, n] \in \N_0$ (Default values are $m=n=1$).
#
# We can also change m and n.
#
# **For countries with badly resolved population data (i.e. Jamaica or Uzbekistan), it can make sense to use nightlights only, i.e. an high exponent of Lit instead of LitPop.**
# Note that if Pop is not used, $Lit = nightlights$ instead of $nightlights+1$.
#
# Let's compare exposure maps for $LitPop=Lit^1Pop^1$ (default); $Lit^3$; and $Pop^1$ Jamaica at a resolution of 60 arcsec.
#
# Please execute one cell after the other:

# %%
ent = LitPop()
res = 60
country = 'JAM' # Try different countries, i.e. 'JAM', 'CHE', 'RWA', 'MEX'
markersize = 3
gridsize = 70
buffer_deg=.04
# The arguments 'exponent' is used to set the power with which Lit and Pop go into LitPop:
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[0, 1])  # Population only
ent.set_geometry_points()
ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer=buffer_deg)
# note: buffer_deg adds a buffer around the plotted data to show the whole country
"""Lit^0 * Pop^1"""
# Out:
# 2019-07-30 09:16:06,570 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 60 arcsec.
# 2019-07-30 09:16:06,571 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:16:06,572 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-07-30 09:16:13,455 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:16:13,455 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:16:13,456 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:16:31,618 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:16:31,619 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:16:31,654 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 26 s
# 2019-07-30 09:16:31,654 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:16:31,655 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:16:31,656 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:16:31,656 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:16:31,658 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:16:31,659 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:16:31,671 - climada.util.coordinates - INFO - Setting geometry points.
# 'Lit^0 * Pop^1'

# %%
# JAMAICA:
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[3, 0]) # Nightlights^3 only
ent.set_geometry_points()
ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer=buffer_deg)
"""Lit^3"""
# Out:
# 2019-07-30 09:16:33,872 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 60 arcsec.
# 2019-07-30 09:16:33,873 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:16:33,874 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-07-30 09:16:41,522 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:16:41,523 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:16:41,524 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:16:59,956 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:16:59,957 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:16:59,998 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 27 s
# 2019-07-30 09:16:59,999 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:17:00,000 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:17:00,000 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:17:00,001 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:17:00,001 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:17:00,002 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:17:00,010 - climada.util.coordinates - INFO - Setting geometry points.
# 'Lit^3'

# %%
ent.set_country(country, res_arcsec=res, reference_year=2014, exponents=[1, 1]) # Default LitPop [1, 1]
ent.set_geometry_points()
ent.plot_hexbin(gridsize = gridsize, linewidth=markersize, buffer=buffer_deg)
"""Lit^1 * Pop^1"""
# Out:
# 2019-07-30 09:17:02,257 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 60 arcsec.
# 2019-07-30 09:17:02,258 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:17:02,259 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_B1_geo_gray.tif.
# 2019-07-30 09:17:11,095 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:17:11,098 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:17:11,100 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:17:30,119 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:17:30,120 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:17:30,159 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 29 s
# 2019-07-30 09:17:30,160 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:17:30,160 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:17:30,162 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:17:30,162 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:17:30,163 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:17:30,164 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:17:30,174 - climada.util.coordinates - INFO - Setting geometry points.
# 'Lit^1 * Pop^1'

# %% [markdown]
# For **Switzerland**, population is resolved on the 3rd administrative level, with 2538 distinct geographical units. Therefore, the purely population-based map is highly resolved.
#
# For **Jamaica**, population is only resolved on the 1st administrative level, with only 14 distinct geographical units. Therefore, the purely population-based map shows large monotonous patches. Still, the combination of Lit and Pop results in a concentration of asset value estimates around the capital city Kingston.

# %% [markdown]
# ### Multiple countries
# Computing LitPop-entities for a list of countries and plot a log-normal exposure map:

# %%
# Initiate GDP-Entity for Tanzania, Rwanda, and Burundi:
ent = LitPop()
countries_list = ['BDI', 'RWA', 'TZA']
ent.set_country(countries_list, res_arcsec=120, reference_year=2014, fin_mode='gdp')
ent.set_geometry_points()
# Out:
# 2019-07-30 09:17:34,214 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 120 arcsec.
# 2019-07-30 09:17:34,217 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:17:34,217 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C2_geo_gray.tif.
# 2019-07-30 09:17:38,634 - climada.entity.exposures.gpw_import - INFO - Reference year: 2014. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:17:38,635 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:17:38,636 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:17:52,472 - climada.util.finance - INFO - GDP TZA 2014: 4.996e+10.
# 2019-07-30 09:17:53,203 - climada.util.finance - INFO - GDP RWA 2014: 8.017e+09.
# 2019-07-30 09:17:54,007 - climada.util.finance - INFO - GDP BDI 2014: 2.706e+09.
# 2019-07-30 09:17:54,136 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:17:54,137 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:17:54,321 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:17:54,322 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:17:54,483 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 7
# 2019-07-30 09:17:54,483 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:17:54,913 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:17:54,920 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:17:55,480 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 24 s
# 2019-07-30 09:17:55,481 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:17:55,481 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:17:55,482 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:17:55,483 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:17:55,483 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:17:55,484 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:17:55,519 - climada.util.coordinates - INFO - Setting geometry points.

# %%
# Plot GDP-Entity for Tanzania, Rwanda, and Burundi:
# ent.plot_hexbin(linewidth=2, buffer=.3) # plot using linear colormap
# ent.plot_hexbin(linewidth=2, buffer=.3, bins='log') # plot using logarithmic colormap
norm=colors.LogNorm(vmin=1.5e2, vmax=1.5e9) # setting range for the log-normal scale
ent.plot_hexbin(linewidth=2, buffer=.3, norm=norm) # log-normal colormap from USD 150 to USD 1'500'000'000.
"""GDP downscaling with LitPop for Tanzania, Rwanda, and Burundi (2014)"""
# Out:
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '
# 'GDP downscaling with LitPop for Tanzania, Rwanda, and Burundi (2014)'

# %% [markdown]
# ## Sub-national (admin-1) GDP as intermediate downscaling layer <a class="anchor" id="admin1"></a>
#
# In order to improve downscaling for countries with large regional differences within, a subnational breakdown of GDP can be used as an intermediate downscaling layer wherever available.
#
# The sub-national (admin-1) GDP-breakdown needs to be added manually as a ".xls"-file to the folder *data/system/GSDP/* in the CLIMADA-directory. Currently, such data is provided for more than 10 countries, including USA, India, and China.
#
# The xls-file requires at least the following columns (with names specified in row 1):
# - State_Province: Names of admin-1 regions, i.e. states, cantons, provinces. Names need to match the naming of admin-1 shapes in the data used by the python package *cartopy.io* (c.f. *shapereader.natural_earth(name='admin_1_states_provinces')*)
# - GSDP_ref: value of sub-national GDP to be used (absolute or relative values)
# - Postal (optional): Alternative identifier of region, if names do not match wioth cartopy. Needs to correspond to the Postal-identifiers used in the shapereader of *cartopy.io*.
#
# Please note that while admin1-GDP will per definition improve the downscaling of *GDP*, it might not neccessarily improve the downscaling quality for other asset bases like produced capital (pc).
#
# *How To:*
#
# The intermediadte downscaling layer can be activated with the option *admin1_calc*.
#
# The option *adm1_scatter* produces a scatter plot to compare the modelled and observed GDP per admin-1 region.

# %%
# Initiate GDP-Entity for Switzerland, with and without admin1_calc:

ent_adm0 = LitPop()
ent_adm0.set_country('CHE', res_arcsec=30, fin_mode='gdp', admin1_calc=False)
ent_adm0.set_geometry_points()

ent_adm1 = LitPop()
ent_adm1.set_country('CHE', res_arcsec=30, fin_mode='gdp', admin1_calc=True)

ent_adm0.check()
ent_adm0.set_geometry_points()
ent_adm1.check()
ent_adm1.set_geometry_points()
print('Done.')
# Out:
# 2019-07-30 09:18:06,149 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30 arcsec.
# 2019-07-30 09:18:06,150 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:18:06,150 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:18:20,303 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:18:20,304 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:18:20,305 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:18:32,034 - climada.util.finance - INFO - GDP CHE 2016: 6.702e+11.
# 2019-07-30 09:18:32,472 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:18:32,479 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:18:33,014 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 28 s
# 2019-07-30 09:18:33,015 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:18:33,015 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:18:33,016 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:18:33,016 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:18:33,017 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:18:33,018 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:18:33,051 - climada.util.coordinates - INFO - Setting geometry points.
# 2019-07-30 09:18:36,418 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 30 arcsec.
# 2019-07-30 09:18:36,419 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (1 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:18:36,420 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:18:51,370 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:18:51,371 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:18:51,372 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:19:03,064 - climada.util.finance - INFO - GDP CHE 2016: 6.702e+11.
# 2019-07-30 09:19:03,492 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:03,502 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:04,036 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Valais.
# 2019-07-30 09:19:04,067 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:04,070 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:04,562 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Ticino.
# 2019-07-30 09:19:04,574 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:04,575 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:04,981 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Graubünden.
# 2019-07-30 09:19:05,026 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:05,028 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:05,633 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Schaffhausen.
# 2019-07-30 09:19:05,634 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:05,635 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:05,638 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:05,639 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:05,924 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Thurgau.
# 2019-07-30 09:19:05,931 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:05,931 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:06,227 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Zürich.
# 2019-07-30 09:19:06,235 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:06,236 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:06,577 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Aargau.
# 2019-07-30 09:19:06,585 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:06,586 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:06,901 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Basel-Stadt.
# 2019-07-30 09:19:06,902 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:06,903 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:07,162 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Basel-Landschaft.
# 2019-07-30 09:19:07,163 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:07,164 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:07,169 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:07,169 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:07,457 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Sankt Gallen.
# 2019-07-30 09:19:07,458 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:07,458 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 1
# 2019-07-30 09:19:07,471 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:07,863 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Solothurn.
# 2019-07-30 09:19:07,864 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 3
# 2019-07-30 09:19:07,864 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:07,872 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:07,873 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:08,189 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Jura.
# 2019-07-30 09:19:08,197 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:08,198 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:08,505 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Genève.
# 2019-07-30 09:19:08,507 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:08,508 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:08,804 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Vaud.
# 2019-07-30 09:19:08,805 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 4
# 2019-07-30 09:19:08,806 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 2
# 2019-07-30 09:19:08,828 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:09,266 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Neuchâtel.
# 2019-07-30 09:19:09,271 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:09,272 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:09,591 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Bern.
# 2019-07-30 09:19:09,593 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 3
# 2019-07-30 09:19:09,593 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 1
# 2019-07-30 09:19:09,653 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:10,213 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Lucerne.
# 2019-07-30 09:19:10,220 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:10,221 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:10,567 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Zug.
# 2019-07-30 09:19:10,570 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:10,570 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:10,865 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Uri.
# 2019-07-30 09:19:10,871 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:10,872 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:11,203 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Schwyz.
# 2019-07-30 09:19:11,209 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:11,210 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:11,570 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Glarus.
# 2019-07-30 09:19:11,574 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:11,575 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:11,890 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Nidwalden.
# 2019-07-30 09:19:11,893 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:11,894 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:12,186 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Fribourg.
# 2019-07-30 09:19:12,188 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 5
# 2019-07-30 09:19:12,188 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:12,203 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:12,203 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:12,549 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Obwalden.
# 2019-07-30 09:19:12,550 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:12,551 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:12,556 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:12,557 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:12,851 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Appenzell Ausserrhoden.
# 2019-07-30 09:19:12,854 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:12,855 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:13,130 - climada.entity.exposures.litpop - DEBUG - Caclulating admin1 for Appenzell Innerrhoden.
# 2019-07-30 09:19:13,131 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 3
# 2019-07-30 09:19:13,131 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:13,134 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:13,135 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:13,463 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 38 s
# 2019-07-30 09:19:13,464 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:19:13,464 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:19:13,465 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:19:13,465 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:19:13,466 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:19:13,466 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:19:13,503 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:19:13,504 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:19:13,504 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:19:13,505 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:19:13,506 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:19:13,507 - climada.util.coordinates - INFO - Setting geometry points.
# 2019-07-30 09:19:15,850 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:19:15,851 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:19:15,852 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:19:15,852 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:19:15,853 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:19:15,854 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:19:15,855 - climada.util.coordinates - INFO - Setting geometry points.
# Done.

# %%
# Plotting:
norm=colors.LogNorm(vmin=1.5e4, vmax=1.5e9) # setting range for the log-normal scale
ent_adm0.plot_hexbin(buffer=.3, norm=norm)
ent_adm1.plot_hexbin(buffer=.3, norm=norm)
print('admin-0: First figure')
print('admin-1: Second figure')
'''Note the small differences in eastern Switzerland.'''
# Out:
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '
# admin-0: First figure
# admin-1: Second figure
# 'Note the small differences in eastern Switzerland.'

# %% [markdown]
# ## Export Exposure Data to CSV <a class="anchor" id="export"></a>
#
# The method ent.to_csv() can be used to export any CLIMADA exposure entity to a CSV-file.
#
# Please refer to the exposure tutorial *climada_entity_Exposures.ipynb* for more info on the export of exposure data!

# %%
# Export LitPop based entity to CSV:
# set output path:
import os
from climada.util.constants import DATA_DIR # default CLIMADA-data directory
output_path = os.path.join(DATA_DIR, 'export') # subfolder export
if not os.path.isdir(output_path): # create output folder if it does not exist
    os.mkdir(output_path)
# set output file path:
output_path = os.path.join(output_path, 'LitPop_Exposure_Burundi_Tanzania_Rwanda.csv')
# Export data:
ent.to_csv(output_path, sep=',')

# display('Exposure entity exported to' + output_path)

# Note that the variable "region_id" in the exported CSV file is a number identifying the country, i.e.:
display('Examples for region_id:')
display('Burundi: ' + str(iso_cntry.get('BDI').numeric))
display('Tanzania: ' + str(iso_cntry.get('TZA').numeric))
display('Rwanda: ' + str(iso_cntry.get('RWA').numeric))
# Out:
# 'Examples for region_id:'
# 'Burundi: 108'
# 'Tanzania: 834'
# 'Rwanda: 646'

# %% [markdown]
# ## Map exposure points to Admin1-Regions <a class="anchor" id="admin1_att"></a>
#
# The method litpop.exposure_set_admin1() can be used to map the data points in any gridded CLIMADA exposure entity to
# admin1-regions, i.e. cantons, states, districts, etc.
#
# Warning: the resolution handed over as a parameter needs to match the resolution of the exposure grid in arc seconds.

# %%
from climada.entity.exposures import litpop as lp
from climada.entity import Exposures
# Map LitPop exposure to districts for Bangladesh:
country_name = ['BGD']
resolution = 600
ent = lp.LitPop()
ent.set_country(country_name, res_arcsec=resolution)
ent = lp.exposure_set_admin1(ent, 600)
# Print first 10 entries:
print(ent.iloc[0:10])
# Select district of Rangpur only and plot exposure:
ent_rangpur = Exposures(ent[ent.admin1 == 'Rangpur'])
ent_rangpur.check()
ent_rangpur.plot_raster()
# Out:
# 2019-07-30 09:19:33,616 - climada.entity.exposures.litpop - INFO - Generating LitPop data at a resolution of 600 arcsec.
# 2019-07-30 09:19:33,618 - climada.entity.exposures.nightlight - DEBUG - Found all required satellite data (2 files) in folder /Users/aznarsig/Documents/Python/climada_python/data/system
# 2019-07-30 09:19:33,618 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_C1_geo_gray.tif.
# 2019-07-30 09:19:36,387 - climada.entity.exposures.litpop - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/BlackMarble_2016_D1_geo_gray.tif.
# 2019-07-30 09:19:38,979 - climada.entity.exposures.gpw_import - INFO - Reference year: 2016. Using nearest available year for GWP population data: 2015
# 2019-07-30 09:19:38,980 - climada.entity.exposures.gpw_import - INFO - GPW Version v4.11
# 2019-07-30 09:19:38,980 - climada.entity.exposures.gpw_import - DEBUG - Importing /Users/aznarsig/Documents/Python/climada_python/data/system/gpw_v4_population_count_rev11_2015_30_sec.tif
# 2019-07-30 09:19:51,068 - climada.util.finance - INFO - GDP BGD 2014: 1.729e+11.
# 2019-07-30 09:19:51,603 - climada.util.finance - INFO - GDP BGD 2016: 2.214e+11.
# 2019-07-30 09:19:51,852 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 22
# 2019-07-30 09:19:51,853 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:51,865 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:51,866 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:51,875 - climada.entity.exposures.litpop - INFO - Creating the LitPop exposure took 19 s
# 2019-07-30 09:19:51,876 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:19:51,876 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:19:51,877 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:19:51,878 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:19:51,879 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:19:51,880 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:19:52,664 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Chittagong.
# 2019-07-30 09:19:52,666 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 6
# 2019-07-30 09:19:52,666 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:52,670 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,671 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,678 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Sylhet.
# 2019-07-30 09:19:52,680 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,681 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,685 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Dhaka.
# 2019-07-30 09:19:52,686 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:52,687 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:52,690 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,691 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,697 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Rangpur.
# 2019-07-30 09:19:52,700 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,701 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,704 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Rajshahi.
# 2019-07-30 09:19:52,707 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,708 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,712 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Khulna.
# 2019-07-30 09:19:52,713 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 2
# 2019-07-30 09:19:52,714 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:52,717 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,717 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
# 2019-07-30 09:19:52,722 - climada.entity.exposures.litpop - DEBUG - Extracting admin1 for Barisal.
# 2019-07-30 09:19:52,723 - climada.entity.exposures.litpop - DEBUG - Detected subshapes: 15
# 2019-07-30 09:19:52,724 - climada.entity.exposures.litpop - DEBUG - of which detected enclaves: 0
# 2019-07-30 09:19:52,729 - climada.entity.exposures.litpop - DEBUG - Removing enclaves...
# 2019-07-30 09:19:52,730 - climada.entity.exposures.litpop - DEBUG - Successfully isolated coordinates from shape
#           value   latitude  longitude  region_id  if_    admin1  admin1_ID
# 0  6.807907e+07  25.916667  88.083333         50    1   Rangpur     5492.0
# 1  6.550797e+08  24.750000  88.083333         50    1  Rajshahi     3255.0
# 2  3.208497e+07  26.083333  88.250000         50    1   Rangpur     5492.0
# 3  9.725386e+07  25.916667  88.250000         50    1   Rangpur     5492.0
# 4  4.105827e+07  24.750000  88.250000         50    1  Rajshahi     3255.0
# 5  3.375228e+08  24.583333  88.250000         50    1  Rajshahi     3255.0
# 6  2.811290e+07  26.250000  88.416667         50    1   Rangpur     5492.0
# 7  1.662658e+09  26.083333  88.416667         50    1   Rangpur     5492.0
# 8  2.946573e+07  25.916667  88.416667         50    1   Rangpur     5492.0
# 9  6.430862e+07  25.750000  88.416667         50    1   Rangpur     5492.0
# 2019-07-30 09:19:52,738 - climada.entity.exposures.base - INFO - crs set to default value: {'init': 'epsg:4326', 'no_defs': True}
# 2019-07-30 09:19:52,739 - climada.entity.exposures.base - INFO - Hazard type not set in if_
# 2019-07-30 09:19:52,740 - climada.entity.exposures.base - INFO - centr_ not set.
# 2019-07-30 09:19:52,741 - climada.entity.exposures.base - INFO - deductible not set.
# 2019-07-30 09:19:52,742 - climada.entity.exposures.base - INFO - cover not set.
# 2019-07-30 09:19:52,743 - climada.entity.exposures.base - INFO - category_id not set.
# 2019-07-30 09:19:52,744 - climada.entity.exposures.base - INFO - geometry not set.
# 2019-07-30 09:19:52,745 - climada.util.coordinates - INFO - Raster from resolution 0.16666666666662877 to 0.16666666666662877.
# /Users/aznarsig/anaconda3/envs/climada_env/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '
